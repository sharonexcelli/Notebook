# %% [markdown]
# # Face Recognition in Python

# %% [markdown]
# ## Locating faces

# %% [markdown]
# Let’s load the image using Pillow in Python:

# %%
from PIL import Image

img = Image.open('orang.jpg')
img = img.convert('RGB')

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=1200x554 at 0x23005303700>

# %% [markdown]
# Let’s get the face locations in the image using the face_recognition

# %%
pip install face_recognition
# Out:
# Collecting face_recognition
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy in c:\users\sharon excelli\anaconda3\lib\site-packages (from face_recognition) (1.21.2)
# Collecting face-recognition-models>=0.3.0
#   Using cached face_recognition_models-0.3.0-py2.py3-none-any.whl
# Requirement already satisfied: Pillow in c:\users\sharon excelli\anaconda3\lib\site-packages (from face_recognition) (8.4.0)
# Requirement already satisfied: Click>=6.0 in c:\users\sharon excelli\anaconda3\lib\site-packages (from face_recognition) (8.0.1)
# Requirement already satisfied: dlib>=19.7 in c:\users\sharon excelli\anaconda3\lib\site-packages (from face_recognition) (19.22.0)
# Requirement already satisfied: colorama in c:\users\sharon excelli\anaconda3\lib\site-packages (from Click>=6.0->face_recognition) (0.4.4)
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import face_recognition

data = np.array(img)
locations = face_recognition.face_locations(data)
print(locations)
# Out:
# [(149, 930, 211, 868), (170, 812, 232, 750), (163, 436, 237, 361), (96, 254, 171, 179), (129, 640, 191, 577)]

# %% [markdown]
# We can see it recognizes 4 faces, each tuple is the rectangle coordinates of a face in the form of top, right, bottom, left.

# %%
print(len(locations))
# Out:
# 5

# %% [markdown]
# ## Practical applications

# %% [markdown]
# Lets use those rectangle coordinates of each face to actually draw a rectangle in those coordinates for each face.

# %%
from PIL import ImageDraw

# We copy the image since we don't want to draw on the original image.
img_copy = img.copy()

draw = ImageDraw.Draw(img_copy)
for location in locations:
    top, right, bottom, left = location
    draw.rectangle(((left, top), (right, bottom)), outline="yellow", width=3)
del(draw)

# %%
img_copy
# Out:
# <PIL.Image.Image image mode=RGB size=1200x554 at 0x2300550E490>
