# %% [markdown]
# ## Library

# %% [markdown]
# Run Library Terlebih Dahulu

# %%
import imageio
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from sklearn.cluster import KMeans
import cv2
from skimage.color import rgb2lab, deltaE_cie76
from collections import Counter
import os 
from PIL import Image
import requests
from io import BytesIO

# %% [markdown]
# ## Tugas 1

# %%
pic=imageio.imread('https://thumbs.dreamstime.com/b/bullet-train-mt-fuji-shinkanzen-passes-shibazakura-spring-shizuoka-japan-92477611.jpg')
plt.figure(figsize=(10,10))
plt.imshow(pic)

# %%
print(pic)
# Out:
# [[[139 203 249]
#   [139 203 249]
#   [139 203 249]
#   ...
#   [136 202 250]
#   [136 202 250]
#   [136 202 250]]
#
#  [[139 203 249]
#   [139 203 249]
#   [139 203 249]
#   ...
#   [136 202 250]
#   [136 202 250]
#   [136 202 250]]
#
#  [[139 203 249]
#   [139 203 249]
#   [139 203 249]
#   ...
#   [136 202 250]
#   [136 202 250]
#   [136 202 250]]
#
#  ...
#
#  [[128 108   0]
#   [129 107   0]
#   [123  98   0]
#   ...
#   [109 160   3]
#   [104 157   7]
#   [104 153   9]]
#
#  [[126 105   0]
#   [127 104   0]
#   [120  95   0]
#   ...
#   [105 161   2]
#   [102 157   4]
#   [ 99 153   7]]
#
#  [[128 107   2]
#   [126 104   2]
#   [118  92   0]
#   ...
#   [100 155   0]
#   [ 95 151   0]
#   [ 91 146   1]]]

# %%
 print('Type of the image : ',type(pic))
 print('Shape of the image : {}'.format(pic.shape))
 print('Hight of the image {}'.format(pic.shape[0]))
 print('Width of the image {}'.format(pic.shape[1]))
 print('Dimension of the Image {}'.format(pic.ndim))
# Out:
# Type of the image :  <class 'imageio.core.util.Array'>
# Shape of the image : (534, 800, 3)
# Hight of the image 534
# Width of the image 800
# Dimension of the Image 3

# %%
 print('Image size {}'.format(pic.size))
 print('Maximum RGB value in this image {}'.format(pic.max()))
 print('Minimum RGB value in this image {}'.format(pic.min()))
# Out:
# Image size 1281600
# Maximum RGB value in this image 255
# Minimum RGB value in this image 0

# %%
 print("The type of image is {}".format(type(pic)))
 print("Shape of the image: {}".format(pic.shape))
# Out:
# The type of image is <class 'imageio.core.util.Array'>
# Shape of the image: (534, 800, 3)

# %%
def RGB_HEX(color):
    return "#{:02x}{:02x}{:02x}".format(int(color[0]), int(color[1]), int(color[2]))

# %%
 def get_colors(image, number_of_colors, show_chart):
     reshaped_image = cv2.resize(pic, (600, 400))
     reshaped_image = reshaped_image.reshape(reshaped_image.shape[0]*reshaped_image.shape[1], 3)
     clf = KMeans(n_clusters = number_of_colors)
     labels = clf.fit_predict(reshaped_image)
     counts = Counter(labels)
     counts = dict(sorted(counts.items()))
     center_colors = clf.cluster_centers_
     ordered_colors = [center_colors[i] for i in counts.keys()]
     hex_colors = [RGB_HEX(ordered_colors[i]) for i in counts.keys()]
     rgb_colors = [ordered_colors[i] for i in counts.keys()]
     if (show_chart):
         plt.figure(figsize = (8, 6))
         plt.pie(counts.values(), labels = hex_colors, colors = hex_colors)
     return rgb_colors

# %%
get_colors(pic, 8, True)
# Out:
# [array([101.56048413, 156.8994994 , 194.49211077]),
#  array([177.71448798, 114.11066891, 114.3878004 ]),
#  array([219.43435909, 217.64644676, 234.92613091]),
#  array([144.47678251, 124.04522508,  30.72723101]),
#  array([218.89998234, 135.60526409, 191.91051051]),
#  array([155.36297941, 204.49933516, 241.55319297]),
#  array([ 67.6491128 , 105.27534854, 118.31432193]),
#  array([81.85240817, 63.41759912, 30.73881051])]

# %% [markdown]
# ## Tugas 2

# %%
response = requests.get('https://thumbs.dreamstime.com/b/bullet-train-mt-fuji-shinkanzen-passes-shibazakura-spring-shizuoka-japan-92477611.jpg')
img = Image.open(BytesIO(response.content))

# %%
print(img.format, img.size, img.mode)
# Out:
# JPEG (800, 534) RGB

# %%
plt.imshow(img)

# %%
#citra awal
response = requests.get('https://thumbs.dreamstime.com/b/bullet-train-mt-fuji-shinkanzen-passes-shibazakura-spring-shizuoka-japan-92477611.jpg')
img = Image.open(BytesIO(response.content))

#template baru
imgA = Image.new('L',(800,534),(0)) #image size x dan y nya sesuaikan (img.size)

# %%
img.getpixel((10,10))
# Out:
# (140, 204, 250)

# %%
#image size x dan y nya sesuaikan (img.size)
for x in range(800):
    for y in range(534):
        warna = img.getpixel((x,y))
        R = warna[0]
        G = warna[1]
        B = warna[2]
        abu3 = int((0.22989*R)+(0.5870*G)+(0.1141*B))
        imgA.putpixel((x,y),(abu3))
plt.imshow(imgA)

# %%
imgA.save('fuji-shinkansen-grey.jpg')

# %%
#image size x dan y nya sesuaikan (img.size)
th = 128
for x in range(800):
    for y in range(534):
        abuabu = imgA.getpixel((x,y))
        if abuabu >= th:
            imgA.putpixel((x,y),(255))
        else:
            imgA.putpixel((x,y),(0))
plt.imshow(imgA)

# %%
imgA.save('fuji-shinkansen-biner.jpg')

# %%
#Histogram citra greyscale
cf = Image.open("./fuji-shinkansen-grey.jpg")
lbr, tgi = (cf.size)

#larik Kosong
baki = []

#Data Histogram
for x in range(lbr):
    for y in range(tgi):
        fxy = cf.getpixel((x,y))
        baki.append(fxy)
gxy = baki

# %%
#tampilan dalam bentuk diagram batang
jb = 255
fig, axs = plt.subplots(1, 2, figsize=(15, 5))
axs[0].imshow(cf)
axs[1].hist(gxy, jb, range=(0, 255), color='red', alpha=0.5)
plt.show()

# %%
#Histogram citra greyscale
cf = Image.open("./fuji-shinkansen-biner.jpg")
lbr, tgi = (cf.size)

#larik Kosong
baki = []

#Data Histogram
for x in range(lbr):
    for y in range(tgi):
        fxy = cf.getpixel((x,y))
        baki.append(fxy)
gxy = baki

# %%
#tampilan dalam bentuk diagram batang
jb = 255
fig, axs = plt.subplots(1, 2, figsize=(15, 5))
axs[0].imshow(cf)
axs[1].hist(gxy, jb, range=(0, 255), color='red', alpha=0.5)
plt.show()

# %%
#Histogram Warna
response = requests.get('https://thumbs.dreamstime.com/b/bullet-train-mt-fuji-shinkanzen-passes-shibazakura-spring-shizuoka-japan-92477611.jpg')
cf = Image.open(BytesIO(response.content))
lbr, tgi = (cf.size)

#larik kosong
bakir = []
bakig = []
bakib = []

#data histogram
for x in range(lbr):
    for y in range(tgi):
        r, g, b = cf.getpixel((x,y))
        bakir.append(r)
        bakig.append(g)
        bakib.append(b)
#gxy = baki

# tampilan dalam bentuk diagram batang
jb = 255
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
#axs[0].imshow(cf)
axs[0].hist(bakir, jb, facecolor ='red', alpha=0.5)
axs[1].hist(bakig, jb, facecolor ='green', alpha=0.5)
axs[2].hist(bakib, jb, facecolor ='blue', alpha=0.5)
plt.show()

# %%
response = requests.get('https://thumbs.dreamstime.com/b/bullet-train-mt-fuji-shinkanzen-passes-shibazakura-spring-shizuoka-japan-92477611.jpg')
cf = Image.open(BytesIO(response.content))
jb = 255
fig, axs = plt.subplots(3, 2, figsize=(10, 10))
axs[0, 0].imshow(cf)
axs[1, 0].imshow(cf)
axs[2, 0].imshow(cf)
axs[0,1].hist(bakir, jb, facecolor ='red', alpha=0.5)
axs[1,1].hist(bakig, jb, facecolor ='green', alpha=0.5)
axs[2,1].hist(bakib, jb, facecolor ='blue', alpha=0.5)
plt.show()

# %%
response = requests.get('https://thumbs.dreamstime.com/b/bullet-train-mt-fuji-shinkanzen-passes-shibazakura-spring-shizuoka-japan-92477611.jpg')
cfW = Image.open(BytesIO(response.content))
r, g, b = cfW.split()

btg = list(range(256))
plt.plot(btg, r.histogram(), 'r')
plt.plot(btg, g.histogram(), 'g')
plt.plot(btg, b.histogram(), 'b')
plt.xlabel('Intensity Value')
plt.ylabel('Count')
plt.legend(['Red_Channel', 'Green_Channel', 'Blue_Channel'])
plt.show()
