# %% [markdown]
# ## Tugas 1

# %%
import imageio
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
import cv2
from skimage.color import rgb2lab, deltaE_cie76
from collections import Counter
import os 
from PIL import Image

# %%
img = Image.open('./gambar.jpg')

# %%
print(img.format, img.size, img.mode)
# Out:
# JPEG (4032, 3016) RGB

# %%
plt.imshow(img)

# %%
from PIL import Image
import matplotlib.pyplot as plt

#citra awal
img=Image.open('./gambar.jpg')

#template baru
imgA = Image.new('L',(276,183),(0))

# %%
plt.imshow(img)

# %%
img.getpixel((10,10))
# Out:
# (215, 230, 253)

# %%
baki = img.getpixel((10,10))
baki[2]
# Out:
# 253

# %%
for x in range(4030):
    for y in range(3014):
        warna = img.getpixel((x,y))
        R = warna[0]
        G = warna[1]
        B = warna[2]
        abu3 = int((0.22989*R)+(0.5870*G)+(0.1141*B))
        imgA.putpixel((x,y),(abu3))
plt.imshow(imgA)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\SHARON~1\AppData\Local\Temp/ipykernel_19284/908962342.py in <module>
#       6         B = warna[2]
#       7         abu3 = int((0.22989*R)+(0.5870*G)+(0.1141*B))
# ----> 8         imgA.putpixel((x,y),(abu3))
#       9 plt.imshow(imgA)
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in putpixel(self, xy, value)
#    1821             # RGB or RGBA value for a P image
#    1822             value = self.palette.getcolor(value, self)
# -> 1823         return self.im.putpixel(xy, value)
#    1824
#    1825     def remap_palette(self, dest_map, source_palette=None):
#
# IndexError: image index out of range
