# %% [markdown]
# ## M8 (17/11/2021) - Deteksi Tepi Sobell
#
# * Vincentius Sharon Excelli Lauder
# * 4IA12
# * 57418241

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import imageio

# %%
img=imageio.imread('https://thumbs.dreamstime.com/b/bullet-train-mt-fuji-shinkanzen-passes-shibazakura-spring-shizuoka-japan-92477611.jpg')
plt.imshow(img)

# %%
def sobelOperator(img):
    container = np.copy(img)
    size = container.shape
    for i in range(1, size[0] - 1):
        for j in range(1, size[1] - 1):
            gx = (img[i - 1][j - 1] + 2*img[i][j - 1] + img[i + 1][j - 1]) - (img[i - 1][j + 1] + 2*img[i][j + 1] + img[i + 1][j + 1])
            gy = (img[i - 1][j - 1] + 2*img[i - 1][j] + img[i - 1][j + 1]) - (img[i + 1][j - 1] + 2*img[i + 1][j] + img[i + 1][j + 1])
            container[i][j] = min(255, np.sqrt(gx**2 + gy**2))
    return container
    pass

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur_img = cv2.GaussianBlur(gray_img, (3, 3), 0)
laplacian = cv2.Laplacian(blur_img, cv2.CV_64F)
plt.imshow(laplacian, cmap='gray')
plt.show()
