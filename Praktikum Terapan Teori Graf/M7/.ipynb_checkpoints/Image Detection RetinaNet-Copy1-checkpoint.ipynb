# %% [markdown]
# # Object Detection with ImageAI

# %% [markdown]
# ## ImageAI

# %% [markdown]
# ### 1. Menyiapkan environment

# %%
pip install tensorflow

# %%
pip install opencv-python

# %%
pip install keras

# %%
pip install imageAI

# %% [markdown]
# ### 2. Import Package

# %%
from imageai.Detection import ObjectDetection

# %% [markdown]
# ### 3. Buat instance dari class ObjectDetection

# %%
detector = ObjectDetection()

# %% [markdown]
# ### 4. Membuat spesifikasi lokasi gambar dan model

# %%
import urllib.request

urllib.request.urlretrieve(
        'https://gitlab.com/andreass.bayu/imageai-repo/-/raw/master/resnet50_coco_best_v2.1.0.h5', 'RetinaNet.h5')
# Out:
# ('RetinaNet.h5', <http.client.HTTPMessage at 0x1e91d874e20>)

# %%
model_path = "RetinaNet.h5"
input_path = "image1.jpeg"
output_path = "newimage1.jpeg"

# %% [markdown]
# ### 5. Pilih fungsi deteksi objek

# %%
detector.setModelTypeAsRetinaNet()

# %% [markdown]
# ### 6. setModelPath()

# %%
detector.setModelPath(model_path)

# %% [markdown]
# ### 7. Load Model

# %%
detector.loadModel()
# Out:
# 2021-04-25 11:59:32,274 [6520] WARNING  tensorflow:193: [JupyterRequire] No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ### 8. Deteksi Image

# %%
detection = detector.detectObjectsFromImage(input_image=input_path, output_image_path=output_path)

# %% [markdown]
# ### 9. Cek Output

# %%
for eachItem in detection:
    print(eachItem["name"] , " : ", eachItem["percentage_probability"])
# Out:
# bus  :  95.51979303359985
# person  :  85.99915504455566
# bicycle  :  81.2700867652893
# person  :  78.73432040214539
# person  :  77.92947888374329
# truck  :  75.84439516067505
# truck  :  71.09194993972778
# person  :  69.79867815971375
# person  :  68.57315301895142
# person  :  61.34217977523804
# car  :  58.00204277038574

# %% [markdown]
# ### 10. Melihat Hasilnya

# %%
from IPython.display import Image
Image(filename='newimage1.jpeg')
